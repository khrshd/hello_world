# %% [markdown]
# # Summary of Analysis

# %% [markdown]
# ## Current work status
#
# - For metric M3x0.5 6H internal thread, touch trigger based 7, 10, 20, 50 & 100 pnts/720o turn and scanning based 7, 10, 20, 50 & 100 pnts/mm pitch cycle and points were collected for 4 locations from the datum(coordinate system);
#
# - Reports including lower and upper limit tolerances were generated;
#
# - Part program to control CMM was generated too comprising point quantity, coordinates, and vectors;
#
# - Applied different tip sizes: 1.5 & 2 mm with 5, 20, & 30 mm extentions;
#
# - Excel and CSV files were also obtained for data analysis.
#
#
# ## Expected/planned work
#
# -
# Do the same work for imperial thread type, specifically #4-40 UNC - 2B.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# The picture on the left is the one descussed in this work and the right one is the next part got go through.

# %% [markdown]
# ### Following results were obtained so far in this study as Dev_X response:
# - From the correlation heatmap, following features were selected for X: 'Act_i','Act_k', 'Act_D', 'Dev_D'
# - Train_Test_RMSE for 4 features =  0.1668812489221055;
# - Intercept value =  0.00044641897988811885;
# - 'Act_i'= 1.235640043299787, 'Act_k'= 79.59463108852702, 'Act_D'= 0.03472450219696186,  'Dev_D'= 0.0209708627419412;
# - Computed null MSE = 0.9022489928371494;
# - Prediction with fitted model = 0.1715071154160658;
# - Coefficients for a non-regularized linear regression: Act_i= 1.2352166884624285, Act_k=79.40119765866156, Act_D= 0.0511064034797397, Dev_D=0.011695957192545209;
# - MSE_Ridge (R^2) = 0.17150952400416244, Best alpha value for Ridge Regression= {'alpha': 0.0001}, Best Score value for Lasso Regression= -0.03545167844958754;
# - MSE_Ridge (R^2)= 0.18941140142788265, Alpha = Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None, normalize=True, random_state=None, solver='auto', tol=0.001);
# - MSE_Lasso (R^2)= 0.17150711541606584, Best alpha value for Lasso Regression= {'alpha': 1e-18}, Best Score value for Lasso Regression= -0.03545415556560301;
# - MSE_Lasso (R^2) = 0.8899605061936344, Alpha = Lasso(alpha=1000, copy_X=True, fit_intercept=True, max_iter=1000, normalize=True, positive=False, precompute=False, random_state=None, selection='cyclic', tol=0.0001, warm_start=False);
# - Examine ridgereg coefficients: Act_i=1.1228300265097546, Act_k=70.7617058476629, Act_D=0.048009622072740114, Dev_D=0.061415793587407494;
# - Examine lassoreg coefficients: Act_i=0.0, Act_k=0.0, Act_D=0.0, Dev_D=0.0.

# %% [markdown]
# ### Future plans
#
# - Predicting Dev_Y, Dev_Z, Dev_i, Dev_j, Dev_k for understanding about every single point with this procedure;
#
# - Try to predict with Logistic Regression values of Clockwise or Counter-clockwise options;
#
# - Check with type of the tip is the best for this work;
#
# - And check where (location wise) we have to use which tip;
#
# - And finally, from Touch trigger, scanning and thread locators, to predict which is appropriate for what application.

# %% [markdown]
# # Thank you

# %% [markdown]
# ## Questions?
